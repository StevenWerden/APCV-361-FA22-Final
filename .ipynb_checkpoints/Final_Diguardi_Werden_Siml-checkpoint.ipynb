# %% [markdown]
# # A Tri-State Comparision of the Cost of Insurance Amongst a Housing Crisis
#
# ### An analysis of the true cost of insurance from the unemployment line
#
#
#
# ##### Nikki Diguardi, Steven Werden, JohnPaul Siml
# ##### University of Arizona
# ##### APCV 361
# ##### Dr. Li Xu
# ##### 12/11/2022

# %% [markdown]
# ## Abstract

# %% [markdown]
# Homelessness is a complex issue with many contributing factors associated with it and this project aims to connect the rates of uninsured individuals to three statistically significant measures that are related to homelessness: severe housing problems, homeownership, and severe housing cost burdens. We are going to see if there is a correlation between being uninsured and the unemployed. This is a significant data point as many would attribute homelessness to substance abuse or other such environmental factors. However, this project aims to prove that homelessness is, in fact, highly correlated to the rising cost of insurance within our country and is responsible for the increase in homelessness in America.
#
# While it is true that many social and economic factors play into homelessness, this project is solely concerned with how the loss of insurance affects and potentially increases the rates of homelessness in America. This project will not discuss many of the other factors that play into homelessness. We can determine that the monetary budget of the household would determine that insurance was not a priority for their budget. However, we would like to acknowledge that fundamentally our approach does not account for every single aspect relating to the problem. We are simply trying to prove that homelessness can result from other factors outside of more traditionally agreed upon influences. We hypothesize that uninsurance is directly correlated to homeownership factors or labor statictics by using several statistically significant approaches to analyze the correlation.

# %% [markdown]
# ## Background

# %% [markdown]
# The Affordable Care Act (ACA) was a necessary step for universal coverage. With it being 12 years since the passing of the bill (March 2010), there should be no reason why people would forego having insurance. From our dataset we will explore the various factors that affect uninsurance in three states. California which has the highest rate of homelessness, uninsured, population, cost of living, and minimum wage. Compared to Wyoming which has the lowest minimum wage, population, and homelessness. By comparing and contrasting these two states, a correlation could be drawn between unemployment and uninsurance rates. However, when dealing with outliers, such as California and Wyoming, it is best to also include a control. South Carolina was chosen as the control state for this paper, since it is in the middle nationwide for both cost of living and population. Our initial approach when trying to prove our stated hypothesis was to graph the number of uninsured individuals in a given state against a particular metric, such as labor force or the number of homeowners in that state.
#
# “Eviction is one of the main causes of homelessness, with ‘one in two homeless adults citing eviction or other rental problems as the cause of his or her homelessness’ ” (Mock, 2021). This is the determination of utilizing the homeowner metric as a main factor in graphing uninsurance. Along with the Affordable Care Act, there are low-income housing which should allow those that cannot afford a house to have one. By using both those government subsidies there should be no-one without insurance or housing. In this project, we will explore the debilitating factors of homelessness and lack of insurance.

# %% [markdown]
# ## Our Initial Methodologies

# %% [markdown]
# Our initial approach when trying to prove our stated hypothesis, was to graph the number of uninsured individuals in a given state against a particular metric, such as unemployment or the number of homeowners in that state. The main goal of this approach was to provide for an easy way to visualize the data, in hopes of directly seeing if increasing uninsured rates would correlate to these given variables. This paper will use several statistically significant approaches to analyze the correlation of uninsured individuals to various homeownership metrics. We started exploring the data with scatterplots and linear regression to enusre there was a high correlation between the datasets. A statistical model will then be developed based on this data and by using cross-validation, a model will then be created based on the data from one state. After our model has been cross validated, California will be tested with data from both Wyoming and South Carolina to test the statistical significance of our proposed correlation between uninsured rates and housing metrics.

# %%
readFile = getData("Project Data.csv")
scatterUninsuredUnemployedNum(readFile, "California")

# %% [markdown]
# By plotting the number of unemployed and uninsured individuals, we can vaildate the correlaiton of the two. As the county numbers on uninsured increased so did the number of unemployed. We assume that this prove the variables are related. This will be shown better in a linear regression of the independant variable, unemployment versus the dependant varible, uninsured.

# %%
scatterUninsuredUnemployedNum(readFile, "Wyoming")

# %%
scatterUninsuredUnemployedNum(readFile, "South Carolina")

# %% [markdown]
# ### Linear Regression and Cross Validation

# %% [markdown]
# After interpreting the scatterplots to have a positive curve and correlation. We went on to create a linear regression model, that we can use to valitdate the strength of the correlation with insurance rates. As the years progressed along the scatterplot, the population would increase. Therefore, the above graphs were showing a false positive correlation. By having the two featured vectors as the axis there would be a correlation as they are graphed together, yet this is a falsehood as it does not prove or disprove our initial theory.

# %%
x = 'Uninsured #'
y = 'Labor Force'

crossValidation(southCarolina, x, y, (1,2,3,4,5,6), 'Mean R-squares for South Carolina')

linearChart(southCarolina, x, y, 2, 'South Carolina')

linearChart(wyoming, 'Uninsured #', 'Unemployed #', (1,2,3,4), 'wyoming')
# Out:
# Mean R-squares for South Carolina
# For dimensionality 1 mean = 0.9557 Std = 0.0134
# For dimensionality 2 mean = 0.9568 Std = 0.0151
# For dimensionality 3 mean = 0.9515 Std = 0.0314
# For dimensionality 4 mean = 0.946 Std = 0.1142
# For dimensionality 5 mean = 0.8777 Std = 0.2453
# For dimensionality 6 mean = 0.6364 Std = 0.8659

# %% [markdown]
# Wow, such a strong linear correlation, right? These charts have R -Squared values of over 0.9! It appears that increasing the number of uninsured individuals increases unemployment, the number of homeowners, and the labor pool! Have we found the reason for uninsurance amongst the population? “Uninsured individuals were more likely to forgo or delay necessary preventive and medical health services for fear of unaffordable medical bills, resulting in worsened health conditions, increased unnecessary morbidity and premature death.” (Truong, Draghi, & Shi, 2022) Those that choose to not have medical proceedures may also be those that do not have employment. The Uninsured increasing with population growth doesn't make sense as the research will show. As the years we researched was 2019-2022 there would have seen a trend of increasing and then decreasing empolyment. As we know the majority of employers carry insurance as benefits. Why would increasing uninsured rates be directly correlated to an increase in labor? And not just by a little bit, but a direct linear relationship? Also, why would uninsured rates lead to more homeowners and not less? Wouldn't people have less money?

# %% [markdown]
# ### Yes, These Charts are Flawed…

# %% [markdown]
# It turns out the issue with the charts above is that each data point represents the given values in a single county within a state. The individual plot is the uninsured rate and the unemployment rate of the individual county therefore the linear relationship is the county not that the data is correlated against each other. We saw that with the R-Squared value being so high in Wyoming, that if we look at the individual county, we can see more information. "In 2019 Health care increased 109% in Natrona County, which is higher than the Wyoming statewide average of 106%. The largest percentage increase was in Teton County, where the cost of living increased 99% during the year of 2020" (Pearce, 2020). It would make sense then, that a strong linear correlation would exist between the various metrics! Larger counties will always have higher values for any metric because they are more populous! These graphs only prove that larger counties have more uninsured people, larger labor forces, and more housing issues! As the years increase so does the population metric and the linear regression does little to show the effects of those uninsured on the homeless population.

# %% [markdown]
# ## Percentages Over Time

# %% [markdown]
# To properly account for this issue, it is necessary to use population percentages, rather than raw population numbers and graph against time rather than another factor. The percentage of a population that is uninsured in a particular county is a universal metric that can be compared against another population percentage, regardless of the disparity between the raw population numbers of each county. By using time, we can provide an accurate average percentage for a given metric. This will allow the data to be hyper focused on how a given state is increasing or decreasing through the years.

# %%
variables = ('Uninsured %', 'Unemployed %','Homeowners %','Severe Housing Problems %')
years = (2019,2020,2021,2022)

chart(data, variables, years, 'All States', False)

# %% [markdown]
# As can be seen in the chart above, we are now displaying percentages, all of which seem rather flat. This is not unexpected since metrics this large rarely fluctuate in a major way and we are only interpolating over four years. However, we are trying to see if there is a correlation between the percentage of uninsured individuals and the effect that it may have on homelessness. Once we have ensured the data is outputting what we are hoping for, there can be a state divide over each year to prove or disprove our theory.

# %% [markdown]
# ## Percentage Differences Over Time

# %% [markdown]
# To better visualize this concept, it is necessary to look at the percentage differences between 2019 and 2022 for each metric. To make this correlation, we set a baseline percentage in 2019 for each relevant metric. Continuing from 2019, we visualize the difference from that original baseline to see if the metrics are affected by uninsured rates.

# %%
variables = ('Uninsured %', 'Unemployed %','Homeowners %','Severe Housing Problems %')
years = (2019,2020,2021,2022)

chart(data, variables, years, 'South Carolina', True)
chart(data, variables, years, 'California', True)
chart(data, variables, years, 'Wyoming', True)
chart(data, variables, years, 'All States', True)

# %% [markdown]
# If our hypothesis is correct, an increase in the uninsured rate would affect the other three variables in a negative way. However, as can be seen across all charts above, this does not seem to be the case. For example, in the chart for California, an increase in the uninsured rates seems to decrease severe housing problems, not increase them! Additionally, before 2021, while uninsured rates are increasing, unemployment is decreasing. And if that was not enough, uninsured rates seem to be directly correlated to an increase in homeowners, not a decrease!
# In the simplest terms, what seems to be going on here is the exact opposite from what we predicted in our hypothesis. Every time uninsured rates increase, the relevant metrics seem to be affected in a beneficial way. While it is beyond the scope of this paper to conclusively prove that this is the case, it does seem to indicate that our hypothesis is very far from being true and is likely incorrect.

# %% [markdown]
# ## Research

# %%
barChart()

# %% [markdown]
# It is also important to note that each state has a very different percentage of uninsured individuals unemployed individuals’ homeowners and severe housing problems per capita. The goal of the charts above is to normalize out these differences so that the changes in them can be seen and compared in a relatively normalized fashion. We would assume with California having the most percentage and Wyoming to have the least yet, in the above bar chart we can see that taking population out causing a normilization affect. Since the numbers are not relative in the fashion we expected, maybe research can aid in this discovery.

# %% [markdown]
# #### Cost of Living
#
# The states we picked were based on the cost of living because homeownership and insurance are tied to how much the household makes. “From 2005 to 2020 the Wyoming statewide cost for housing increased by 70%, health care increased by 106% and the median earning increased by 41%. Therefore, the cost of living did not meet the increase in housing or health care.” (Pearce, 2020) With the ever changing market for insurance and housing there has to be a simialrity that can aid both factors. “A single adult, living in Wyoming, needs to earn 10.24 (USD) per hour working full time to be able to meet his or her basic needs, which is nearly three dollars per hour more than the federal minimum wage rate (7.25 (USD) per hour in 2020) or double Wyoming’s minimum wage rate of 5.15 (USD) per hour.” (Pearce, 2020)
#
# After seeing that there was not the correlation we expected, the research has been corobrating the dataset. We were under the impression that unemployment and the housing crisis affects uninsurance, yet it might be the other way around. “The majority of the jobs in Wyoming are in mining therefore there is less volatility in the employment rate. Due to the nature of mining also requires those people to have coverage with insurance.”(Schuhmann & Jensen, 2022). The environmental factors can not be over looked, by Wyoming major resource being mining there would be a higher need for insurance and California having an issue that neither South Carolina or Wyoming have.
#
# Of those living in California, there are homeless but there are also the undocumented since the data set was strictly about the variety of census there would be no data for those non-citizens. “In 2014, approximately 61% of undocumented immigrants and 49% of noncitizens were uninsured in LA county,” (Zhang, 335) This article summarizes the types of health care that people of each documentation status have access to. This was measured by income, and a sample of the population insured according to origin and citizenship. We have a similar gauge with the labor factor, as having a job contributes to having insurance (most employers have insurance as a benefit). Yet, if the undocumented could not have insurance within the United States, there would have to be a factor based on homeowners.

# %%
variables = ('Uninsured %','Homeowners %')
years = (2019,2020,2021,2022)

chart(data, variables, years, 'All States', True)

# %% [markdown]
# #### Housing Crisis
#
# Affordable housing is harder to make because the building and development costs keep rising. “However, despite the high cost of housing, the most recent American Housing Survey found that 1.5 million households in the United States were living in homes that were severely inadequate.“ (Mock, 2021) If the house is low-income does not mean that it could be habitatble. Understanding the decline of the construction labor market and the higher price for contractors is important because identifying opportunities that California can utilize to bring down the price of development can help solve the housing crisis.
#
# “Many of the costs detailed in this study are not unique to affordable housing—rising construction and labor costs, delays caused by lengthy entitlement processes, local development fees and design requirements, and environmental building standards are driving up the costs of market-rate units as well.” (Reid, 23) Our dataset includes housing burden, which is the number of homeowners that over pay for their mortgage compared to the income produced by the household. We explore this feature as a contributing factor to not having insurance, yet we found that it was an adverse effect. “California’s rising affordable housing development costs stand in direct opposition to its goals in addressing the housing crisis. The research presented here confirms that costs on 9% LIHTC (Low-Income Housing Tax Credit) new construction projects have significantly outpaced inflation, meaning that more public subsidy dollars are building fewer and fewer affordable units.” (Reid, 28) Those that have a hard time affording hosuing have an issue insuring their families because it is not the highest prioity for the household.

# %%
interpretData()

# %% [markdown]
# With the above graphs we can see that the density of the severe housing burden is not weighted heavily to one side which shows the standard devation to be on par with our conclusion. The housing burden is based on the populaiton and is not a contributing factor to the insurance rates. “Eviction is one of the main causes of homelessness, with ‘one in two homeless adults citing eviction or other rental problems as the cause of his or her homelessness.’ ” (Mock, 2021) This paper aimed to prove that homelessness is, in fact, highly correlated to the rising cost of insurance within our country and is responsible for the increase in homelessness in America. That was not the case as the data and research showed.

# %%
variables = ('Severe Housing Cost Burden %','Homeowners %')
years = (2019,2020,2021,2022)

chart(data, variables, years, 'All States', True)

# %% [markdown]
# ## Conclusion
#
# It has become apparent that homelessness is due to the many factors that we have presented such as being uninsured, unemployed and most importantly, suffering from a high housing cost burden.  Clearly, homeowners who suffer a high percentage on their housing cost burden which strongly contributes to their overall debt-to-income ratio, will also suffer the consequences of eviction which is primarily uninsurance. At least, that's what our initial hypothesis was to prove in this project. On the contrary, our data shows that the rate of uninsured individuals has a negative correlation to other metrics such as unemployment and severe housing burden. Our research also came to the same conclusion and that “lessening barriers to healthcare access for noncitizens could be crucial to generate labor productivity, reducing uninsured rates, preventing uncompensated care, and improving resource shortage among safety net providers" (Zhang, 342). Therefore, we can conclude that by changing the entry into getting healthcare, labor can increase and lessen homelessness.

# %% [markdown]
# ## References
#
# Mock. (2021). BLACKLISTED: AN ARGUMENT FOR EVICTION RECORD SUPPRESSION IN SOUTH CAROLINA IN RESPONSE TO THE HOUSING CRISIS. Charleston Law Review, 15(2), 529.
#
# Pearce, D. M. (2020). The Self-Sufficiency Standard for Wyoming 2020.
# https://selfsufficiencystandard.org/wp-content/uploads/2021/11/WY2020_SSS.pdf
#
# Reid, C., NAPOLITANO, A., & STAMBUK-TORRES, B. E. A. T. R. I. Z. (2020). The costs of affordable housing production: Insights from California’s 9% low-income housing tax credit program. Berkeley, CA: Terner Center for Housing Innovation, UC Berkeley.
#
# Schuhmann, R., & Jensen, J. (2022). Time for a Significant Reimagining of Government in Wyoming?. California Journal of Politics and Policy, 14(1).
#
# Truong, K., Bedi, J. S., Zhang, L., Draghi, B., & Shi, L. (2022, April). Predicting Areas with High Concentration of the Long-Term Uninsured and Their Association with Emergency Department Usage by Uninsured Patients in South Carolina. In Healthcare (Vol. 10, No. 5, p. 771). MDPI
#
# Zhang, X. (2021). Immigrants’ access to care under the Affordable Care Act: An examination of California. International Journal of Healthcare Management, 14(2), 335-344.

# %% [markdown]
# # Project Code
# This is the code used in this project

# %% [markdown]
# ## Data Load

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.cluster import KMeans
from scipy.stats import linregress
# %matplotlib inline

plt.rcParams["figure.figsize"] = (8,5)
plt.style.use('fivethirtyeight')
data = readData("Project Data.csv")

southCarolina = data[data.State == 'South Carolina']
california = data[data.State == 'California']
wyoming = data[data.State == 'Wyoming']

# %% [markdown]
# ## Data Code

# %%
def readData(filename):
    df = pd.read_csv(filename)
    return df

# %%
#Column Names
#Just copy and paste the names from here to retrieve the data



#General Info
'''
'Year'
'State'
'County'
'''


#Uninsured
'''
'Uninsured #'
'Uninsured %'
'Uninsured 95% CI - Low'
'Uninsured 95% CI - High'
'Uninsured Z-Score'
'''


#Adults Uninsured
'''
'Adults Uninsured #'
'Adults Uninsured %'
'Adults Uninsured 95% CI - Low'
'Adults Uninsured 95% CI - High'
'''


#Children Uninsured
'''
'Children Uninsured #'
'Children Uninsured %'
'Children Uninsured 95% CI - Low'
'Children Uninsured 95% CI - High'
'''

#Unemployment
'''
'Unemployed #'
'Labor Force'
'Unemployed %'
'Unemployed Z-Score'
'''


#Severe Housing Problems
'''
'Severe Housing Problems %'
'Severe housing problems 95% CI - Low'
'Severe housing problems 95% CI - High'
'Severe Housing Cost Burden'
'Overcrowding'
'Inadequate Facilities'
'Severe housing problems Z-Score'
'Households with Severe Cost Burden #'
'Severe Housing Cost Burden %'
'Severe housing cost burden 95% CI - Low'
'Severe housing cost burden 95% CI - High'
'''

#Homeowners
'''
'Homeowners #'
'Homeowners %'
'Homeowners 95% CI - Low'
'Homeowners 95% CI - High'
'''
# Out:
# "\n'Homeowners #'\n'Homeowners %'\n'Homeowners 95% CI - Low'\n'Homeowners 95% CI - High'\n"

# %% [markdown]
# ## Linear Regression Code

# %%
def getData(fileName):
    
    data = pd.read_csv(fileName,skiprows=1, sep='\t', names=['Age', 'Length'])
    df = pd.DataFrame(data, columns= ['Age','Length'])

    sortedDF = df.sort_values(by=['Age'])

    ages = sortedDF['Age'].to_numpy()
    length = sortedDF['Length'].to_numpy()

    return (ages, length)

# %%
def plotData(xVals, yVals):
    xVals = np.array(xVals)
    yVals = np.array(yVals)
    xVals = xVals
    
    
    plt.plot(xVals, yVals, 'bo',
               label = '')
    plt.show()

# %%
def labelPlot(x,y,title):
    plt.title(title)
    plt.xlabel(x)
    plt.ylabel(y)

# %%
def basic(df, x, y,title):
    df = df .sort_values([x])
    xVal = df[x]
    yVal = df[y]
    labelPlot(x,y,title)
    plotData(xVal, yVal)

# %%
def fitData(xVals, yVals):
    xVals = np.array(xVals)
    yVals = np.array(yVals)
    
    plt.plot(xVals, yVals, 'bo',
               label = 'Measured points') 
    
    model = np.polyfit(xVals, yVals, 2)
    
    estYVals = np.polyval(model, xVals)
    
    plt.plot(xVals, estYVals, 'r',
               label = 'Linear fit, k = '
               + str(round(1/model[0], 5)))
    plt.legend(loc = 'best')
    plt.show()

# %%
def rSquared(observed, predicted):
    error = ((predicted - observed)**2).sum()
    meanError = error/len(observed)
    return 1 - (meanError/np.var(observed))

# %%
def genFits(xVals, yVals, degrees):
    models = []
    
    if isinstance(degrees, int):
        model = np.polyfit(xVals, yVals, degrees)
        return model
    
    for d in degrees:
        model = np.polyfit(xVals, yVals, d)
        models.append(model)
    return models

# %%
def testFits(models, degrees, xVals, yVals):
    plt.plot(xVals, yVals, 'o', label = 'Data')
    
    if isinstance(degrees, int):
        estYVals = np.polyval(models, xVals)
        error = rSquared(yVals, estYVals)
        plt.plot(xVals, estYVals,linewidth=3.0,
                   label = 'Fit of degree '\
                   + str(degrees)\
                   + ', R2 = ' + str(round(error, 5)))
        plt.legend(loc = 'best')
        plt.show()
        return
    
    for i in range(len(models)):
        estYVals = np.polyval(models[i], xVals)
        error = rSquared(yVals, estYVals)
        plt.plot(xVals, estYVals,linewidth=3.0,
                   label = 'Fit of degree '\
                   + str(degrees[i])\
                   + ', R2 = ' + str(round(error, 5)))
    plt.legend(loc = 'best')
    plt.show()

# %%
def linearChart(df, x, y, deg, title):
    df = df .sort_values([x])
    xVal = df[x]
    yVal = df[y]
    degrees = deg
    labelPlot(x,y,title)
    models = genFits(xVal, yVal, degrees)
    testFits(models, degrees, xVal, yVal)

# %% [markdown]
# ## Cross Validation Code

# %%
def splitData(xVals, yVals):
    toTrain = random.sample(range(len(xVals)),
                            len(xVals)//2)
    trainX, trainY, testX, testY = [],[],[],[]
    for i in range(len(xVals)):
        if i in toTrain:
            trainX.append(xVals[i])
            trainY.append(yVals[i])
        else:
            testX.append(xVals[i])
            testY.append(yVals[i])
    return trainX, trainY, testX, testY

# %%
def runTrials( xVals, yVals, dim, equ, msg):
    #Initialize things 
    numSubsets = 100
    dimensions = dim
    trialList = {}
    
    xVals = np.array(xVals)
    yVals = np.array(yVals)

    for d in dimensions:
        trialList[d] = []
    
    #Train, Test, and Report
    for f in range(numSubsets):
        trainX, trainY, testX, testY = splitData(xVals, yVals)
        for d in dimensions:
            model = np.polyfit(trainX, trainY, d)
            estYVals = np.polyval(model, testX)
            trialList[d].append(equ(testY, estYVals))
            
    print(msg)
    
    for d in dimensions:
        mean = round(sum(trialList[d])/len(trialList[d]), 4)
        sd = round(np.std(trialList[d]), 4)
        print('For dimensionality', d, 'mean =', mean,
              'Std =', sd)

# %%
def crossValidation(df, x, y, deg, title):
    df = df .sort_values([x])
    xVal = df[x]
    yVal = df[y]
    degrees = deg
    models = genFits(xVal, yVal, degrees)
    runTrials(xVal, yVal, degrees , rSquared, title)

# %% [markdown]
# ## Percentages

# %%
def chart(data, variables, years, state, diff = False):
    
    tick_spacing = 1
    fig, ax = plt.subplots(1,1)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

    for var in variables:
        stateVars = []
        offset = 0
        msg = var
        
        for year in years:
    
            if state == 'All States':
                temp = data[(data['Year'] == year)]
            else:
                temp = data[(data['Year'] == year) & (data['State'] == state)]
        
            if diff and year == years[0]:
                offset = temp[var].mean()
                msg += ' Diff'
        
            stateVars.append(temp[var].mean() - offset)
        
        plt.plot(years, stateVars, label = msg)
        
    plt.title(state)
    plt.legend(loc = 'best')
    plt.show()
    plt.show()

# %%
def chartStates(data, variable, years, states, diff = False):
    
    tick_spacing = 1
    fig, ax = plt.subplots(1,1)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
        
    for state in states:
        stateVars = []
        offset = 0
        msg = state+" "+variable

        for year in years:

            temp = data[(data['Year'] == year) & (data['State'] == state)]

            if diff and year == years[0]:
                offset = temp[variable].mean()
                msg += ' Diff'

            stateVars.append(temp[variable].mean() - offset)

        plt.plot(years, stateVars, label = msg)

    plt.title(variable)
    plt.legend(loc = 'best')
    plt.show()
    plt.show()

# %%
def barChartData(data, variables, states):
    
    bars = {}
    
    for state in states:
        stateVars = []
        temp = data[data['State'] == state]
        
        for var in variables:
            stateVars.append(temp[var].mean())
            
        bars[state] = stateVars
        
    return bars

# %%
def barChart():
    labels = ['Unemployed %', 'Uninsured %', 'Homeowners %', 'Home Problems %']

    variables = ('Unemployed %', 'Uninsured %', 'Homeowners %', 'Severe Housing Problems %')

    states = ('South Carolina','California','Wyoming')

    stateData = barChartData(data, variables, states)

    x = np.arange(len(labels))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots()
    ax.bar(x - (width*1.0), stateData['South Carolina'], width, label='South Carolina')
    ax.bar(x - (width*0.0), stateData['Wyoming'], width, label='Wyoming')
    ax.bar(x + (width*1.0), stateData['California'], width, label='California')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Percent')
    ax.set_title('Metrics By State')
    ax.set_xticks(x, labels)
    ax.legend()


    fig.tight_layout()

    plt.show()

# %% [markdown]
# ## Bar Charts

# %%
def openAll(fileName):
    df = pd.read_csv(fileName)
    return df

def getData(fileName):
    readFile = openAll(fileName)
    return readFile

def getStateYear(readFile, year, state):
    readYear = readFile.loc[lambda readFile: readFile["Year"] == year]
    readStateYear = readYear.loc[lambda readYear: readYear["State"] == state]
    return readStateYear

def sumCells(data, column):
    returnValue = 0
    for cell in data[column]:
        returnValue += cell
    return returnValue

def percentBarGraph2022(readFile):
    stateValues = [[], [], []]
    states = ["California", "Wyoming", "South Carolina"]
    for i in range(len(stateValues)):
        state2022 = getStateYear(readFile, 2022, states[i])
        stateValues[i].append(sumCells(state2022, "Uninsured %"))
        stateValues[i].append(sumCells(state2022, "Unemployed %"))
        stateValues[i].append(sumCells(state2022, "Homeowners %"))
        stateValues[i].append(sumCells(state2022, "Severe Housing Cost Burden %"))
    xvalue = np.arange(4)
    w = 0.2
    ax = plt.subplot(111)
    axisLabels = ["Uninsured", "Unemployed", "Homeowners", "Cost Burden"]
    california = ax.bar(xvalue-0.2, stateValues[0], width = w, align='center', color="blue", edgecolor = "black")
    wyoming = ax.bar(xvalue, stateValues[1], width = w, align='center', color="orange", edgecolor = "black")
    southCarolina = ax.bar(xvalue+0.2, stateValues[2], width = w, align='center', color="green", edgecolor = "black")
    plt.xticks(xvalue, axisLabels)
    ax.legend((california[0], wyoming[0], southCarolina[0]), ('CA', 'WY', 'SC'))
    plt.title("States' % Value of Homemlessness Factors in 2022")
    plt.ylabel("Sum of County Percentages")
    plt.show()

def scatterUninsuredUnemployedNum(readFile, state):
    years = [2019, 2020, 2021, 2022]
    fig, ax = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True) # For each state, plot the four years in a 2x2 subplot
    for j in range(len(years)): 
        readYear = readFile.loc[lambda readFile: readFile["Year"] == years[j]]
        currentStateX = []
        currentStateY = []
        readStateYear = readYear.loc[lambda readYear: readYear["State"] == state]
        for cell in readStateYear["Uninsured #"]:
            if(cell < 500000): # Filter outlier in CA
                currentStateX.append(cell)
        for cell in readStateYear["Unemployed #"]:
            if(cell < 200000): # Filter outlier in CA
                currentStateY.append(cell)
        plt.subplot(2, 2, j + 1)
        plt.scatter(currentStateX, currentStateY)
    fig.suptitle(state + " Uninsured # vs Unemployed # from 2019-2022")
    
def histHousingBurden2022(readFile):
    states = ["California", "Wyoming", "South Carolina"]
    colors = ["blue", "orange", "green"]
    readYear = readFile.loc[lambda readFile: readFile["Year"] == 2022]
    for i in range(len(states)):
        currentState = []
        readStateYear = readYear.loc[lambda readYear: readYear["State"] == states[i]]
        for cell in readStateYear["Severe Housing Cost Burden %"]:
            currentState.append(cell)
        plt.hist(currentState, color=colors[i], edgecolor = "black")
        plt.title(states[i] + "'s Severe Housing Cost Burden % in 2022")
        plt.xlabel("Housing Cost Burden")
        plt.ylabel("Frequency")
        readStateYear["Severe Housing Cost Burden %"].plot.kde(color='red', secondary_y=True)
        plt.show()
    
def interpretData():
    pd.set_option('display.max_rows', None) # Allows for all rows to be printed
    readFile = getData("Project Data.csv")
    
    # Present the data
    #percentBarGraph2022(readFile)
    
    # Analyze the frequency of severe housing cost burden % in 2022 for each state
    histHousingBurden2022(readFile)
