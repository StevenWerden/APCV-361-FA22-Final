# %% [markdown]
# # Final Project (Need Name)

# %% [markdown]
# ## Introduction

# %% [markdown]
# # Part 1: Data Visualized
# Write up here

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('fivethirtyeight')
data = read_data("Project Data.csv")

southCarolina = data[data.State == 'South Carolina']
california = data[data.State == 'California']
wyoming = data[data.State == 'Wyoming']

# %%
interpretData()

# %% [markdown]
# ## Unemployment \ Uninsured

# %%
x = 'Uninsured #'
y = 'Unemployed #'

chart(southCarolina, x, y, 'South Carolina')
chart(california, x, y, 'California')
chart(wyoming, x, y, 'Wyoming')

# %% [markdown]
# ## Homeowners \ Uninsured

# %%
x = 'Uninsured #'
y = 'Homeowners #'

chart(southCarolina, x, y, 'South Carolina')
chart(california, x, y, 'California')
chart(wyoming, x, y, 'Wyoming')

# %% [markdown]
# ## Labor \ Uninsured

# %%
x = 'Uninsured #'
y = 'Labor Force'

chart(southCarolina, x, y, 'South Carolina')
chart(california, x, y, 'California')
chart(wyoming, x, y, 'Wyoming')

# %% [markdown]
# # Affordances Going Foward

# %% [markdown]
# ## Calfornia Dataset

# %% [markdown]
# The Calfornia dataset has some very large outliers, which for the purposes of this paper are not important. Any Californa data used in the follow chart will have been filtered to remove these outliers to better visualize the majority of the data from the state.

# %%
#Data
californiaFiltered = california
californiaFiltered = removeOutlier(californiaFiltered, 'Uninsured #')
californiaFiltered = removeOutlier(californiaFiltered, 'Unemployed #')
californiaFiltered = removeOutlier(californiaFiltered, 'Labor Force')
californiaFiltered = removeOutlier(californiaFiltered, 'Homeowners #')

# %% [markdown]
# ## South Carolina Dataset

# %% [markdown]
# Upon futher research, the homeowner data from South Carolina is not accurate, as can be seen in the homeowever / uninsured chart. This is due to an issue with how the state reports this number. South Carolina will be omitted from future charts with this metric.

# %% [markdown]
# # Part 2: Linear Regression Results

# %% [markdown]
# Write up on linear regression here

# %% [markdown]
# ## Unemployment \ Uninsured
# Write up here

# %%
x = 'Uninsured %'
y = 'Unemployed %'

linearChart(southCarolina, x, y, (1,2,3,4), 'South Carolina')
linearChart(californiaFiltered, x, y, (1,2,3,4), 'California')
linearChart(wyoming, x, y, (1,2,3,4), 'Wyoming')

# %%
xVals = np.array(wyoming['Year'])
zVals = np.array(wyoming['Homeowners #'])
yVals = np.array(wyoming['Uninsured #'])
    
plt.plot(xVals, yVals, 'bo',label = '')
plt.subplot(xVals, zVals, 'bo',label = '')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 6>()
#       3 yVals = np.array(wyoming['Uninsured #'])
#       5 plt.plot(xVals, yVals, 'bo',label = '')
# ----> 6 plt.subplot(xVals, zVals, 'bo',label = '')
#       7 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:597, in SubplotSpec._from_subplot_args(figure, args)
#     593 else:
#     594     raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     595                     f"{len(args)} were given")
# --> 597 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     598 if gs is None:
#     599     gs = GridSpec(rows, cols, figure=figure)
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:222, in GridSpecBase._check_gridspec_exists(figure, nrows, ncols)
#     215         if hasattr(gs, 'get_topmost_subplotspec'):
#     216             # This is needed for colorbar gridspec layouts.
#     217             # This is probably OK because this whole logic tree
#     218             # is for when the user is doing simple things with the
#     219             # add_subplot command.  For complicated layouts
#     220             # like subgridspecs the proper gridspec is passed in...
#     221             gs = gs.get_topmost_subplotspec().get_gridspec()
# --> 222         if gs.get_geometry() == (nrows, ncols):
#     223             return gs
#     224 # else gridspec not found:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## Homeowners \ Uninsured
# Write up here

# %%
x = 'Uninsured #'
y = 'Homeowners #'

linearChart(californiaFiltered, x, y, (1,2,3,4), 'California')
linearChart(wyoming, x, y, (1,2,3,4), 'Wyoming')

# %% [markdown]
# ## Labor \ Uninsured

# %%
x = 'Uninsured #'
y = 'Labor Force'

linearChart(southCarolina, x, y, (1,2,3,4), 'South Carolina')
linearChart(californiaFiltered, x, y, (1,2,3,4), 'California')
linearChart(wyoming, x, y, (1,2,3,4), 'Wyoming')

# %% [markdown]
# # Part 3: Cross Validation Results

# %% [markdown]
# ## Unemployment \ Uninsured
# Write up here

# %%
x = 'Uninsured #'
y = 'Unemployed #'

crossValidation(southCarolina, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(southCarolina, x, y, 1, 'South Carolina')

crossValidation(californiaFiltered, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(californiaFiltered, x, y, 3, 'California')

crossValidation(wyoming, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(wyoming, x, y, 4, 'Wyoming')
# Out:
# Mean R-squares for test data
# For dimensionality 1 mean = 0.7906 Std = 0.0598
# For dimensionality 2 mean = 0.7681 Std = 0.0874
# For dimensionality 3 mean = 0.7497 Std = 0.0914
# For dimensionality 4 mean = 0.6968 Std = 0.2413
# For dimensionality 5 mean = 0.5196 Std = 0.8212
# For dimensionality 6 mean = -0.1053 Std = 2.9049
# Mean R-squares for test data
# For dimensionality 1 mean = 0.7806 Std = 0.041
# For dimensionality 2 mean = 0.7822 Std = 0.0404
# For dimensionality 3 mean = 0.7752 Std = 0.0425
# For dimensionality 4 mean = 0.7557 Std = 0.112
# For dimensionality 5 mean = 0.7047 Std = 0.2188
# For dimensionality 6 mean = 0.4308 Std = 1.5369
# Mean R-squares for test data
# For dimensionality 1 mean = 0.8751 Std = 0.0358
# For dimensionality 2 mean = 0.8728 Std = 0.0329
# For dimensionality 3 mean = 0.8706 Std = 0.0349
# For dimensionality 4 mean = 0.8753 Std = 0.0389
# For dimensionality 5 mean = 0.8607 Std = 0.0623
# For dimensionality 6 mean = 0.8454 Std = 0.0687

# %% [markdown]
# ## Homeowners \ Uninsured
# Write up here

# %%
x = 'Uninsured #'
y = 'Homeowners #'

crossValidation(californiaFiltered, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(californiaFiltered, x, y, 3, 'California')

crossValidation(wyoming, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(wyoming, x, y, 4, 'Wyoming')
# Out:
# Mean R-squares for test data
# For dimensionality 1 mean = 0.9121 Std = 0.053
# For dimensionality 2 mean = 0.925 Std = 0.1895
# For dimensionality 3 mean = -5.434 Std = 28.47
# For dimensionality 4 mean = -926.7827 Std = 4555.9435
# For dimensionality 5 mean = -117088.3218 Std = 567224.8017
# For dimensionality 6 mean = -114977499.2545 Std = 445216461.3022
# Mean R-squares for test data
# For dimensionality 1 mean = 0.8942 Std = 0.0305
# For dimensionality 2 mean = 0.8931 Std = 0.0567
# For dimensionality 3 mean = 0.866 Std = 0.2249
# For dimensionality 4 mean = 0.8312 Std = 0.3307
# For dimensionality 5 mean = 0.81 Std = 0.34
# For dimensionality 6 mean = 0.7216 Std = 0.7767

# %% [markdown]
# ## Labor \ Uninsured

# %%
x = 'Uninsured #'
y = 'Labor Force'

crossValidation(southCarolina, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(southCarolina, x, y, 1, 'South Carolina')

crossValidation(californiaFiltered, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(californiaFiltered, x, y, 3, 'California')

crossValidation(wyoming, x, y, (1,2,3,4,5,6), 'Mean R-squares for test data')

linearChart(wyoming, x, y, 4, 'Wyoming')
# Out:
# Mean R-squares for test data
# For dimensionality 1 mean = 0.9556 Std = 0.013
# For dimensionality 2 mean = 0.9573 Std = 0.0114
# For dimensionality 3 mean = 0.9389 Std = 0.0736
# For dimensionality 4 mean = 0.8661 Std = 0.4377
# For dimensionality 5 mean = 0.7735 Std = 0.7747
# For dimensionality 6 mean = 0.3212 Std = 3.4134
# Mean R-squares for test data
# For dimensionality 1 mean = 0.9639 Std = 0.0184
# For dimensionality 2 mean = 0.9168 Std = 0.3147
# For dimensionality 3 mean = -3.0924 Std = 28.5579
# For dimensionality 4 mean = -1398.9501 Std = 9783.0118
# For dimensionality 5 mean = -59436.3817 Std = 373792.5214
# For dimensionality 6 mean = -46899886.8008 Std = 278904120.6928
# Mean R-squares for test data
# For dimensionality 1 mean = 0.9108 Std = 0.0247
# For dimensionality 2 mean = 0.8981 Std = 0.0757
# For dimensionality 3 mean = 0.8583 Std = 0.3161
# For dimensionality 4 mean = 0.7518 Std = 0.7991
# For dimensionality 5 mean = 0.2118 Std = 4.0879
# For dimensionality 6 mean = -0.2889 Std = 6.6542

# %% [markdown]
# # Project Conclusion
# Final Thoughts here

# %% [markdown]
# # Project Code
# This is the code used in this project

# %% [markdown]
# ## Data Code

# %%
def read_data(filename):
    df = pd.read_csv(filename)
    return df

# %%
#Column Names
#Just copy and paste the names from here to retrieve the data



#General Info
'''
'Year'
'State'
'County'
'''


#Uninsured
'''
'Uninsured #'
'Uninsured %'
'Uninsured 95% CI - Low'
'Uninsured 95% CI - High'
'Uninsured Z-Score'
'''


#Adults Uninsured
'''
'Adults Uninsured #'
'Adults Uninsured %'
'Adults Uninsured 95% CI - Low'
'Adults Uninsured 95% CI - High'
'''


#Children Uninsured
'''
'Children Uninsured #'
'Children Uninsured %'
'Children Uninsured 95% CI - Low'
'Children Uninsured 95% CI - High'
'''

#Unemployment
'''
'Unemployed #'
'Labor Force'
'Unemployed %'
'Unemployed Z-Score'
'''


#Severe Housing Problems
'''
'Severe Housing Problems %'
'Severe housing problems 95% CI - Low'
'Severe housing problems 95% CI - High'
'Severe Housing Cost Burden'
'Overcrowding'
'Inadequate Facilities'
'Severe housing problems Z-Score'
'Households with Severe Cost Burden #'
'Severe Housing Cost Burden %'
'Severe housing cost burden 95% CI - Low'
'Severe housing cost burden 95% CI - High'
'''

#Homeowners
'''
'Homeowners #'
'Homeowners %'
'Homeowners 95% CI - Low'
'Homeowners 95% CI - High'
'''
# Out:
# "\n'Homeowners #'\n'Homeowners %'\n'Homeowners 95% CI - Low'\n'Homeowners 95% CI - High'\n"

# %% [markdown]
# ## Linear Regression Code

# %%
def getData(fileName):
    
    data = pd.read_csv(fileName,skiprows=1, sep='\t', names=['Age', 'Length'])
    df = pd.DataFrame(data, columns= ['Age','Length'])

    sortedDF = df.sort_values(by=['Age'])

    ages = sortedDF['Age'].to_numpy()
    length = sortedDF['Length'].to_numpy()

    return (ages, length)

# %%
def plotData(xVals, yVals):
    xVals = np.array(xVals)
    yVals = np.array(yVals)
    xVals = xVals
    
    
    plt.plot(xVals, yVals, 'bo',
               label = '')
    plt.show()

# %%
def labelPlot(x,y,title):
    plt.title(title)
    plt.xlabel(x)
    plt.ylabel(y)

# %%
def chart(df, x, y,title):
    df = df .sort_values([x])
    xVal = df[x]
    yVal = df[y]
    labelPlot(x,y,title)
    plotData(xVal, yVal)

# %%
def fitData(xVals, yVals):
    xVals = np.array(xVals)
    yVals = np.array(yVals)
    
    plt.plot(xVals, yVals, 'bo',
               label = 'Measured points') 
    
    model = np.polyfit(xVals, yVals, 2)
    
    estYVals = np.polyval(model, xVals)
    
    plt.plot(xVals, estYVals, 'r',
               label = 'Linear fit, k = '
               + str(round(1/model[0], 5)))
    plt.legend(loc = 'best')
    plt.show()

# %%
def rSquared(observed, predicted):
    error = ((predicted - observed)**2).sum()
    meanError = error/len(observed)
    return 1 - (meanError/np.var(observed))

# %%
def genFits(xVals, yVals, degrees):
    models = []
    
    if isinstance(degrees, int):
        model = np.polyfit(xVals, yVals, degrees)
        return model
    
    for d in degrees:
        model = np.polyfit(xVals, yVals, d)
        models.append(model)
    return models

# %%
def testFits(models, degrees, xVals, yVals):
    plt.plot(xVals, yVals, 'o', label = 'Data')
    
    if isinstance(degrees, int):
        estYVals = np.polyval(models, xVals)
        error = rSquared(yVals, estYVals)
        plt.plot(xVals, estYVals,linewidth=3.0,
                   label = 'Fit of degree '\
                   + str(degrees)\
                   + ', R2 = ' + str(round(error, 5)))
        plt.legend(loc = 'best')
        plt.show()
        return
    
    for i in range(len(models)):
        estYVals = np.polyval(models[i], xVals)
        error = rSquared(yVals, estYVals)
        plt.plot(xVals, estYVals,linewidth=3.0,
                   label = 'Fit of degree '\
                   + str(degrees[i])\
                   + ', R2 = ' + str(round(error, 5)))
    plt.legend(loc = 'best')
    plt.show()

# %%
def linearChart(df, x, y, deg, title):
    df = df .sort_values([x])
    xVal = df[x]
    yVal = df[y]
    degrees = deg
    labelPlot(x,y,title)
    models = genFits(xVal, yVal, degrees)
    testFits(models, degrees, xVal, yVal)

# %%
def removeOutlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %% [markdown]
# ## Cross Validation Code

# %%
def splitData(xVals, yVals):
    toTrain = random.sample(range(len(xVals)),
                            len(xVals)//2)
    trainX, trainY, testX, testY = [],[],[],[]
    for i in range(len(xVals)):
        if i in toTrain:
            trainX.append(xVals[i])
            trainY.append(yVals[i])
        else:
            testX.append(xVals[i])
            testY.append(yVals[i])
    return trainX, trainY, testX, testY

# %%
def runTrials( xVals, yVals, dim, equ, msg):
    #Initialize things 
    numSubsets = 100
    dimensions = dim
    trialList = {}
    
    xVals = np.array(xVals)
    yVals = np.array(yVals)

    for d in dimensions:
        trialList[d] = []
    
    #Train, Test, and Report
    for f in range(numSubsets):
        trainX, trainY, testX, testY = splitData(xVals, yVals)
        for d in dimensions:
            model = np.polyfit(trainX, trainY, d)
            estYVals = np.polyval(model, testX)
            trialList[d].append(equ(testY, estYVals))
            
    print(msg)
    
    for d in dimensions:
        mean = round(sum(trialList[d])/len(trialList[d]), 4)
        sd = round(np.std(trialList[d]), 4)
        print('For dimensionality', d, 'mean =', mean,
              'Std =', sd)

# %%
def crossValidation(df, x, y, deg, title):
    df = df .sort_values([x])
    xVal = df[x]
    yVal = df[y]
    degrees = deg
    models = genFits(xVal, yVal, degrees)
    runTrials(xVal, yVal, degrees , rSquared, title)

# %% [markdown]
# ## Bar Charts

# %%
def openAll(fileName):
    df = pd.read_csv(fileName)
    return df

def getData(fileName):
    readFile = openAll(fileName)
    return readFile

def getStateYear(readFile, year, state):
    readYear = readFile.loc[lambda readFile: readFile["Year"] == year]
    readStateYear = readYear.loc[lambda readYear: readYear["State"] == state]
    return readStateYear

def sumCells(data, column):
    returnValue = 0
    for cell in data[column]:
        returnValue += cell
    return returnValue

def percentBarGraph2022(readFile):
    stateValues = [[], [], []]
    states = ["California", "Wyoming", "South Carolina"]
    for i in range(len(stateValues)):
        state2022 = getStateYear(readFile, 2022, states[i])
        stateValues[i].append(sumCells(state2022, "Uninsured %"))
        stateValues[i].append(sumCells(state2022, "Unemployed %"))
        stateValues[i].append(sumCells(state2022, "Homeowners %"))
        stateValues[i].append(sumCells(state2022, "Severe Housing Cost Burden %"))
    xvalue = np.arange(4)
    w = 0.2
    ax = plt.subplot(111)
    axisLabels = ["Uninsured", "Unemployed", "Homeowners", "Cost Burden"]
    california = ax.bar(xvalue-0.2, stateValues[0], width = w, align='center', color="blue", edgecolor = "black")
    wyoming = ax.bar(xvalue, stateValues[1], width = w, align='center', color="orange", edgecolor = "black")
    southCarolina = ax.bar(xvalue+0.2, stateValues[2], width = w, align='center', color="green", edgecolor = "black")
    plt.xticks(xvalue, axisLabels)
    ax.legend((california[0], wyoming[0], southCarolina[0]), ('CA', 'WY', 'SC'))
    plt.title("States' % Value of Homemlessness Factors in 2022")
    plt.ylabel("Sum of County Percentages")
    plt.show()

def scatterUninsuredUnemployedNum2022(readFile):
    states = ["California", "Wyoming", "South Carolina"]
    readYear = readFile.loc[lambda readFile: readFile["Year"] == 2022]
    for i in range(len(states)):
        currentStateX = []
        currentStateY = []
        readStateYear = readYear.loc[lambda readYear: readYear["State"] == states[i]]
        for cell in readStateYear["Uninsured #"]:
            currentStateY.append(cell)
        for cell in readStateYear["Unemployed #"]:
            currentStateX.append(cell)
        plt.scatter(currentStateX, currentStateY)
        #plt.title()
        plt.show()
    
def histHousingBurden2022(readFile):
    states = ["California", "Wyoming", "South Carolina"]
    colors = ["blue", "orange", "green"]
    readYear = readFile.loc[lambda readFile: readFile["Year"] == 2022]
    for i in range(len(states)):
        currentState = []
        readStateYear = readYear.loc[lambda readYear: readYear["State"] == states[i]]
        for cell in readStateYear["Severe Housing Cost Burden %"]:
            currentState.append(cell)
        plt.hist(currentState, color=colors[i], edgecolor = "black")
        plt.title(states[i] + "'s Severe Housing Cost Burden % in 2022")
        plt.xlabel("Housing Cost Burden")
        plt.ylabel("Frequency")
        readStateYear["Severe Housing Cost Burden %"].plot.kde(color='red', secondary_y=True)
        plt.show()
    
def interpretData():
    pd.set_option('display.max_rows', None) # Allows for all rows to be printed
    readFile = getData("Project Data.csv")
    
    # Present the data
    percentBarGraph2022(readFile)
    
    # Analyze the trend of uninsured # vs unemployed # in 2022 for each state
    #scatterUninsuredUnemployedNum2022(readFile) 
    # Nikki did these already
    
    # Analyze the frequency of severe housing cost burden % in 2022 for each state
    histHousingBurden2022(readFile)
    
    #TODO: make plot that analyzes the trend of something between years
    #Maybe scatterplot for same state with different colors for each year
